# %%
from sqlalchemy import create_engine 
from sqlalchemy import MetaData,Table,Column,Integer,String
from sqlalchemy.orm import mapper,sessionmaker
import requests
import ijson 
import json
import pandas as pd
import time
get_ipython().run_line_magic('matplotlib', 'inline')
import matplotlib.pyplot as plt
from datetime import datetime
from createtables import PlayingInTheatre,PlayingInMovieOnTv   
class ProcessDataForAndellaClient:
  #  http://data.tmsapi.com/v1.1/movies/showings?startDate=2020-11-26&zip=78701&api_key=npd3vc7pmp49qkuz3b5tdsp5
#http://data.tmsapi.com/v1.1/movies/airings?lineupId=USA-TX42500-X&startDateTime=2020-11-26T09:30Z&api_key=npd3vc7pmp49qkuz3b5tdsp5
    def __init__(self):
        self.api_1  =None
        self.api_2  = None
        self.r1= ''  # str for local tv  
        self.r2='' # str aired on tv 
        self.responsetextlocal=None 
        self.responsetexttvline=None

        #this is the func to  get data from the two apis
    def processrequestsandgetdata(self,api_1,api_2):
        self.api_1 = api_1
        self.api_2  = api_2
        try:           
            self.r1= requests.get(self.api_1).json()
        except ConnectionResetError:
            print('connection problem .......')
        except:
            print('something went  wrong.....for first response')
        print('called  first requests ........')
#         time.sleep(2)
        try:             
            self.r2= requests.get(self.api_2).json()
        except ConnectionResetError:
            print('connection problem ....... for second response.........')
        except:
            print('something went  wrong..... for second response.........')         
        print('called second requests ......')
        self.responsetextlocal= json.dumps(self.r1,indent=2) # for response format in str
        self.responsetexttvline= json.dumps(self.r2,indent=2) # response formatted in str
        self.listoftheatre=[]
        return 
    
    # this function write data to database
    def processrequestdata(self):
        engine=create_engine('mysql+pymysql://apiuser:apiuser@localhost/apisamplecalls',echo=True) # connecting to database  using sqlalchemy
#         connection  =  engine.connect()
        print('connection successful .........')
        # for table two 
        Session = sessionmaker(bind=engine)
        session  =  Session()
        Session2 = sessionmaker(bind=engine)
        session2  =  Session2()
        for dat in self.r2: 
            startTime  =dat['startTime']
            title = dat['program']['title']
            tmsId  = dat['program']['tmsId']
            rootId  = dat['program']['rootId']
            theatreorchannels  = dat['station']['channel']
            if 'releaseYear' in dat:
                if dat['program']['releaseYear'] == None:
                    print('empty ...........')
                else:
                    releaseYear = dat['program'].get('releaseYear')
            else:
                releaseYear=''
#             releaseYear  = dat['program'].get('releaseYear')
            description=None
            if 'shortDescription' in dat:
                if dat['program']['shortDescription'] ==None :
                    print('empty ........')
                    pass
                else:
                    description=dat['program'].get('shortDescription')
            else:
                description=''
#             description  = dat['program'].get('description')
#             description =''
            genres=None
            if 'genres' in dat:
                if dat['program']['genres'] == None:                  
                    print('empty genres .....')
                    pass
                else:
                     genres  = dat['program']['genres']
        
#             genres  = dat['program']['genres']
            print('in the loop')
            print('genres ...',genres)
            if genres ==None:              
                    p = PlayingInMovieOnTv(id=0,tmsId=tmsId,rootId=rootId,title=title,releaseyear=releaseYear,genrestype='',theatreorchannels=theatreorchannels,description=description) 
                    session2.add(p)
            else:
                for i in genres:                   
                    genrestype=i
                    p = PlayingInMovieOnTv(id=0,tmsId=tmsId,rootId=rootId,title=title,releaseyear=releaseYear,genrestype=genrestype,theatreorchannels=theatreorchannels,description=description) 
                    session2.add(p)
            session2.commit()
#         time.sleep(2.5)
         # for table one
        listoftheatretableobject = [] 
        print('processing the second response object .......')
        for data in self.r1:
            #startTime  =data['startTime']
            title = data['title']
            tmsId  = data['tmsId']
            rootId  = data['rootId']
            genres=None
            genre  = ''
            if 'genres' in data:             
                if data['genres'] == None:                  
                    print('empty genres .....')
                    pass
                else:             
                    genres  = data['genres']                   
                    for g in genres:                    
                        genre  = genre+g+','
                        print(type(genres),genres)
            else:
                genre=''
            releaseYear  = data.get('releaseYear')
            print(releaseYear)
            year  = releaseYear
            description  = data.get('shortDescription')
#             description =''
            counter  = 0   
            genrestype = genre
            print('genrestype ',genrestype)
            for i in range(len(data['showtimes'])):
                theatreorchannels=data['showtimes'][i]['theatre']['name']
                p = PlayingInTheatre(id=0,tmsId=tmsId,rootId=rootId,title=title,releaseyear=year,genrestype=genrestype,theatreorchannels=theatreorchannels,description=description) 
                print('inserting into database ....')
                listoftheatretableobject.append(p)
            for gen in range(len(genrestype.split(','))):
                if gen == ',':
                    continue
                for myp in range(len(listoftheatretableobject)):
                    listoftheatretableobject[myp].genrestype = gen
                    session.add(listoftheatretableobject[myp])
        session.commit() 
        return  
    def processandfilterdatawithpandas(self):       
        engine=create_engine('mysql+pymysql://apiuser:apiuser@localhost/apisamplecalls',echo=True) # connecting to database  using sqlalchemy
#     connection  =  engine.connect()
        print('connection successful')
    #for top five 
#     combinequerybaseontheatreorchannels = '''
#     select count(theatreorchannels) as 'theatreorchannels',count(genrestype) as 'genre',theatreorchannels,genrestype,
#     title group by theatreorchannels,genrestype order by genrestype limit 5  
#     '''   
    # the below task can also be solved from sql into pandas but i have chosen to use the pandas approach 
     # solving the problem by manipulating each dataframes 
     #and grouping the each dataframe based on genretype .
        df =pd.read_sql_table('playinginmovieontv',engine,columns=['title','releaseyear','genrestype','theatreorchannels']) # picking out the columns  i want from the  table
        df2  = pd.read_sql_table('playingintheatre',engine,columns=['title','releaseyear','genrestype','theatreorchannels'])
        print('data loaded successfully into pandas dataframe')
#     1.	Group both the Movie lists based on ‘Genre’
        group_df  = df.groupby([ "title","releaseyear","theatreorchannels"],sort=True , as_index=False)["genrestype"].size() # first list 
        group_df2  = df2.groupby(["title","releaseyear","theatreorchannels"],sort=True , as_index=False)["genrestype"].size() # second list 
        print('the first  movie list ..............')
        print(group_df.head(15))
        print('the second  movie list ......................')
        print(group_df2.head(15))
        print('printing the  merge group ..........')
        frames = [group_df,group_df2]
        group_merge = pd.concat(frames,ignore_index=True, keys=['channels', 'theatre'])
        print(group_merge.head(5))
    #     2.	Combine the movie lists (Theatre and Channel movies) based on the Genres
    # select theatre and genre from the first movie list 
        df1 = df[['theatreorchannels', 'genrestype','title']]
        print('movie ',df1.theatreorchannels.dtype)
        print(df1.head(5))
     # select theatre and genre from the second movie list 
        df_2 = df2[['theatreorchannels', 'genrestype','title']]
        print(df_2.head(5))
        print('theatre ',df_2.theatreorchannels.dtype)      
    # combine the two based  on genretype
        pd_merge  = pd.merge(df, df_2, on='genrestype')
        print('printing out the  combine set of theatreorchannels and genretype')
        print( pd_merge.head(5))
        result_group= pd_merge.sort_values(by=['genrestype'], ascending=True)
        result  = pd_merge.groupby(['title_x','title_y','theatreorchannels_x','theatreorchannels_y'],sort=True , as_index=False)["genrestype"].count()
#     3.	Return the Top 5 Genres with the highest movie count along with the movie details 
        print('printing out the top five  based on genres')
        print(result_group.head(5))
        print('printing the top five based  on ..............genre according to the number of  occurrence ........')
        print(result.head(5))
        print('printing out the chart .........')
#     result[['title_x','title_y','genretype']].hist()
        result.plot(x="theatreorchannels_x",kind="bar") #
        print('finish executing ..............')
        return
data  = ProcessDataForAndellaClient()
my_dateformoviesontv = datetime.now().strftime("%Y-%m-%dT%H:%MZ") # dynamic date and time generation
print(my_dateformoviesontv)
# 2020-11-26T18:10Z 
# npd3vc7pmp49qkuz3b5tdsp5
# fh68by6te646ghfej39sxywp
my_date = datetime.now().strftime("%Y-%m-%d")
api_1  = f'http://data.tmsapi.com/v1.1/movies/showings?startDate={my_date}&zip=78701&api_key=fh68by6te646ghfej39sxywp'
api_2  = f'http://data.tmsapi.com/v1.1/movies/airings?lineupId=USA-TX42500-X&startDateTime={my_dateformoviesontv}&api_key=fh68by6te646ghfej39sxywp'
data.processrequestsandgetdata(api_1,api_2)
data.processrequestdata()
data.processandfilterdatawithpandas() #load data from database with pandas and process 
responseforlocaltv  = data.responsetextlocal
responseforairtv   = data.responsetexttvline
r1=  data.r1  # respnse for local theatre
r2  = data.r2 # response for movie on tv
theatrecounter = 0
movietvcounter  = 0
# Out:
# tables are about to be created ...........
# 2020-11-29 19:27:52,516 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2020-11-29 19:27:52,516 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-29 19:27:52,516 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2020-11-29 19:27:52,525 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-29 19:27:52,525 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2020-11-29 19:27:52,525 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-29 19:27:52,533 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2020-11-29 19:27:52,533 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-29 19:27:52,533 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2020-11-29 19:27:52,533 INFO sqlalchemy.engine.base.Engine {}
# ...
